# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk import pos_tag

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger_eng')

text = "NLTK is a leading platform. It helps in building Python programs for NLP."

sentences = sent_tokenize(text)
print("Sentence Tokenization:")
print(sentences)

words = word_tokenize(text)
print("\nWord Tokenization:")
print(words)

stop_words = set(stopwords.words('english'))
filtered_words = [w for w in words if w.lower() not in stop_words]
print("\nAfter Stop Word Removal:")
print(filtered_words)

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(w) for w in filtered_words]
print("\nAfter Stemming:")
print(stemmed_words)

pos_tags = pos_tag(words)
print("\nPOS Tagging:")
print(pos_tags)
# Out:
# Sentence Tokenization:
# ['NLTK is a leading platform.', 'It helps in building Python programs for NLP.']
#
# Word Tokenization:
# ['NLTK', 'is', 'a', 'leading', 'platform', '.', 'It', 'helps', 'in', 'building', 'Python', 'programs', 'for', 'NLP', '.']
#
# After Stop Word Removal:
# ['NLTK', 'leading', 'platform', '.', 'helps', 'building', 'Python', 'programs', 'NLP', '.']
#
# After Stemming:
# ['nltk', 'lead', 'platform', '.', 'help', 'build', 'python', 'program', 'nlp', '.']
#
# POS Tagging:
# [('NLTK', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('leading', 'JJ'), ('platform', 'NN'), ('.', '.'), ('It', 'PRP'), ('helps', 'VBZ'), ('in', 'IN'), ('building', 'VBG'), ('Python', 'NNP'), ('programs', 'NNS'), ('for', 'IN'), ('NLP', 'NNP'), ('.', '.')]
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading punkt_tab: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading averaged_perceptron_tagger_eng: <urlopen
# [nltk_data]     error [Errno 11001] getaddrinfo failed>
